# %% [markdown]
# For my portion of the analysis, I focused on exploring the relationship between total compensation (both tdc1 and tdc2) and tax-related metrics, including effective tax rate and deferred tax percentage. The goal was to understand how different levels of compensation impact a company's tax efficiency and tax obligations. I began by crafting and executing queries to identify companies with the highest total compensation, those with the highest effective tax rates, and those exhibiting negative or low deferred tax percentages. This allowed for a targeted exploration of companies with unique compensation structures. I then conducted exploratory data analysis and visualized the distribution of compensation and tax-related variables across different compensation brackets, using scatter plots, boxplots, and tax efficiency analyses. By examining these relationships, I aimed to uncover any significant patterns or discrepancies, and to contribute to the overall understanding of compensation and tax behavior within the dataset. These findings will support the team’s broader analysis of how compensation practices influence a company’s tax strategies.

# %%
#import pandas
import pandas as pd
import numpy as np
import time

# %%
#import the merged dataset from team's GitHub
mergedData = "https://raw.githubusercontent.com/causeyca21/CSC442Group/refs/heads/main/merged_data.csv"

data = pd.read_csv(mergedData)

data
# Out:
#        gvkey   tic        act         at      capx       che       cogs  \
# 0       1004   AIR   1097.900   1833.100    29.500    81.800   1591.300
# 1       1075   PNW   1926.967  24661.153  1889.934     4.955   3077.308
# 2       1161   AMD  16768.000  67885.000   546.000  5773.000  10833.000
# 3       1209   APD   5200.500  32002.500  4626.400  1949.200   7474.700
# 4       1230   ALK   2705.000  14613.000  1494.000  1791.000   8106.000
# ...      ...   ...        ...        ...       ...       ...        ...
# 1147  264193  SNDR   1110.900   4557.200   807.600   159.600   4668.400
# 1148  264416  UCTT    893.200   1867.700    75.800   307.000   1411.100
# 1149  287462    FF    290.546    367.081     6.022   220.189    316.888
# 1150  317264   LPG    236.299   1708.914    68.785   148.797     98.309
# 1151  328795   ACA    912.000   3577.900   203.500   104.800   1709.600
#
#             ib        pi       revt  ...  opt_unex_unexer_est_val  othcomp  \
# 0       89.800   121.200   1990.600  ...                 1684.328  482.257
# 1      501.557   595.693   4695.991  ...                    0.000   34.831
# 2      854.000   508.000  22680.000  ...                    0.000   28.711
# 3     2292.800  2882.400  12600.000  ...                    0.000  401.795
# 4      235.000   323.000  10426.000  ...                    0.000  386.446
# ...        ...       ...        ...  ...                      ...      ...
# 1147   238.500   306.100   5498.900  ...                  216.553  149.056
# 1148   -31.100   -11.300   1734.500  ...                    0.000   11.997
# 1149    37.382    37.383    368.250  ...                    0.000   51.000
# 1150   172.444   172.444    392.151  ...                    0.000    9.900
# 1151   159.200   195.900   2307.900  ...                    0.000   20.770
#
#         salary  stock_awards  stock_unvest_val      tdc1        tdc2  \
# 0     1050.000      3272.152         13379.485  7865.228   12846.484
# 1     1125.000      5028.405          3237.829  3753.703    3753.703
# 2     1200.000     21848.258          9531.088  8500.023  123065.368
# 3     1350.000     17074.629         18076.385  9994.108    9994.108
# 4      637.692      7969.932             0.000  8570.214    8570.214
# ...        ...           ...               ...       ...         ...
# 1147   941.667      4703.533           268.218  1090.723    1090.723
# 1148   736.538      3507.146          2986.943  5043.765    5043.765
# 1149   442.000         0.000             0.000   699.000     699.000
# 1150   650.000      2381.285          3095.991  1914.900    1914.900
# 1151   980.500      4189.222          9991.319  2284.745    2284.745
#
#       total_sec  Stock as % of total compensation  \
# 0      7865.450                          0.416028
# 1      9322.192                          1.339585
# 2     30348.281                          2.570376
# 3     22078.099                          1.708470
# 4     10313.054                          0.929957
# ...         ...                               ...
# 1147   5794.256                          4.312308
# 1148   5043.765                          0.695343
# 1149    699.000                          0.000000
# 1150   4296.185                          1.243556
# 1151   6474.120                          1.833562
#
#      Options as % of total compensation
# 0                              0.737331
# 1                              0.000000
# 2                             14.165121
# 3                              0.000000
# 4                              0.000000
# ...                                 ...
# 1147                           0.000000
# 1148                           0.000000
# 1149                           0.000000
# 1150                           0.000000
# 1151                           0.000000
#
# [1152 rows x 34 columns]

# %%
start = time.time()

# Selecting relevant columns for analysis
comp_query = data[['tdc1', 'tdc2', 'txt', 'revt', 'txc', 'pi', 'txdc', 'at',
                       'Total Income Taxes as % of pretax income', 'gvkey', 'tic',
                       'Total Income Deferred Taxes as % of pretax income',
                       'Total Income Deferred Taxes as % of total assets']]

end = time.time()
print(f"Time taken to select columns: {end - start} seconds")
print("Number of rows returned: ", comp_query.shape[0], "; Number of columns returned:", len(comp_query.columns))

comp_query
# Out:
# Time taken to select columns: 0.0019381046295166016 seconds
# Number of rows returned:  1152 ; Number of columns returned: 13
#           tdc1        tdc2      txt       revt      txc        pi      txdc  \
# 0     7865.228   12846.484   31.400   1990.600   33.600   121.200    -2.200
# 1     3753.703    3753.703   76.912   4695.991   24.126   595.693    52.755
# 2     8500.023  123065.368 -346.000  22680.000  673.000   508.000 -1019.000
# 3     9994.108    9994.108  551.200  12600.000  575.900  2882.400   -24.700
# 4     8570.214    8570.214   88.000  10426.000   -7.000   323.000    81.000
# ...        ...         ...      ...        ...      ...       ...       ...
# 1147  1090.723    1090.723   67.600   5498.900   11.800   306.100    55.800
# 1148  5043.765    5043.765   10.900   1734.500   23.100   -11.300   -12.400
# 1149   699.000     699.000    0.001    368.250    0.001    37.383     0.000
# 1150  1914.900    1914.900    0.000    392.151    0.000   172.444     0.000
# 1151  2284.745    2284.745   36.700   2307.900    4.900   195.900    31.800
#
#              at  Total Income Taxes as % of pretax income   gvkey   tic  \
# 0      1833.100                                  0.259076    1004   AIR
# 1     24661.153                                  0.129113    1075   PNW
# 2     67885.000                                 -0.681102    1161   AMD
# 3     32002.500                                  0.191230    1209   APD
# 4     14613.000                                  0.272446    1230   ALK
# ...         ...                                       ...     ...   ...
# 1147   4557.200                                  0.220843  264193  SNDR
# 1148   1867.700                                 -0.964602  264416  UCTT
# 1149    367.081                                  0.000027  287462    FF
# 1150   1708.914                                  0.000000  317264   LPG
# 1151   3577.900                                  0.187340  328795   ACA
#
#       Total Income Deferred Taxes as % of pretax income  \
# 0                                             -0.018152
# 1                                              0.088561
# 2                                             -2.005906
# 3                                             -0.008569
# 4                                              0.250774
# ...                                                 ...
# 1147                                           0.182293
# 1148                                           1.097345
# 1149                                           0.000000
# 1150                                           0.000000
# 1151                                           0.162328
#
#       Total Income Deferred Taxes as % of total assets
# 0                                            -0.001200
# 1                                             0.002139
# 2                                            -0.015011
# 3                                            -0.000772
# 4                                             0.005543
# ...                                                ...
# 1147                                          0.012244
# 1148                                         -0.006639
# 1149                                          0.000000
# 1150                                          0.000000
# 1151                                          0.008888
#
# [1152 rows x 13 columns]

# %%
# Checking for missing values
missing_values = comp_query.isnull().sum()
print("Missing Values in Key Variables:\n", missing_values)
# Out:
# Missing Values in Key Variables:
#  tdc1                                                 0
# tdc2                                                 0
# txt                                                  0
# revt                                                 0
# txc                                                  0
# pi                                                   0
# txdc                                                 0
# at                                                   0
# Total Income Taxes as % of pretax income             0
# gvkey                                                0
# tic                                                  0
# Total Income Deferred Taxes as % of pretax income    0
# Total Income Deferred Taxes as % of total assets     0
# dtype: int64

# %%
# Summary statistics
summary_stats = comp_query.describe()
print("\nSummary Statistics:\n", summary_stats)
# Out:
# Summary Statistics:
#                  tdc1           tdc2           txt           revt  \
# count    1152.000000    1152.000000   1152.000000    1152.000000
# mean     8445.110425   11182.149141    230.205627   11700.748558
# std      8823.625910   33852.865160   1051.426960   37424.957200
# min         0.000000       0.000000  -5001.000000       0.000000
# 25%      3394.220500    3214.197250      6.789500    1002.057500
# 50%      6192.017000    6207.086000     43.100000    2803.892500
# 75%     11068.594750   11803.380000    161.694000    7776.725000
# max    149429.486000  942779.918000  16950.000000  608481.000000
#
#                 txc             pi         txdc             at  \
# count   1152.000000    1152.000000  1152.000000    1152.000000
# mean     291.928968    1187.761806   -56.378129   15713.817089
# std     1182.333873    5249.220283   437.869706   39829.528322
# min     -484.000000  -10237.000000 -6349.000000       2.308000
# 25%       10.398000      33.223000   -32.475000    1426.201250
# 50%       46.974500     215.888500    -4.226500    3662.823500
# 75%      178.046000     814.425000     6.579500   12146.165500
# max    23009.000000  113736.000000  3037.000000  411976.000000
#
#        Total Income Taxes as % of pretax income          gvkey  \
# count                               1152.000000    1152.000000
# mean                                   0.194361   54572.414931
# std                                    2.284329   62806.565633
# min                                  -32.937500    1004.000000
# 25%                                    0.110772    9437.500000
# 50%                                    0.208466   25875.000000
# 75%                                    0.252199   65629.000000
# max                                   64.023569  328795.000000
#
#        Total Income Deferred Taxes as % of pretax income  \
# count                                        1152.000000
# mean                                           -0.007388
# std                                             2.861176
# min                                           -38.205387
# 25%                                            -0.087234
# 50%                                            -0.004511
# 75%                                             0.064571
# max                                            72.062500
#
#        Total Income Deferred Taxes as % of total assets
# count                                       1152.000000
# mean                                          -0.004347
# std                                            0.024585
# min                                           -0.397853
# 25%                                           -0.008201
# 50%                                           -0.001748
# 75%                                            0.002149
# max                                            0.266047

# %%
# Correlation matrix for numerical columns only
numerical_comp_query = comp_query.select_dtypes(include=np.number)  # Select numerical columns
correlation_matrix = numerical_comp_query.corr()
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                                                         tdc1      tdc2  \
# tdc1                                               1.000000  0.234672
# tdc2                                               0.234672  1.000000
# txt                                                0.341562  0.028075
# revt                                               0.317419  0.086632
# txc                                                0.378654  0.118584
# pi                                                 0.366565  0.107378
# txdc                                              -0.156062 -0.242926
# at                                                 0.427075  0.132998
# Total Income Taxes as % of pretax income           0.006133 -0.018041
# gvkey                                             -0.039486 -0.013484
# Total Income Deferred Taxes as % of pretax income -0.017832 -0.017925
# Total Income Deferred Taxes as % of total assets  -0.022141 -0.144829
#
#                                                         txt      revt  \
# tdc1                                               0.341562  0.317419
# tdc2                                               0.028075  0.086632
# txt                                                1.000000  0.656883
# revt                                               0.656883  1.000000
# txc                                                0.929059  0.659602
# pi                                                 0.927890  0.641823
# txdc                                              -0.012105 -0.139922
# at                                                 0.703843  0.736987
# Total Income Taxes as % of pretax income           0.007794 -0.000960
# gvkey                                             -0.085733 -0.093126
# Total Income Deferred Taxes as % of pretax income  0.003274 -0.001427
# Total Income Deferred Taxes as % of total assets   0.092959  0.016442
#
#                                                         txc        pi  \
# tdc1                                               0.378654  0.366565
# tdc2                                               0.118584  0.107378
# txt                                                0.929059  0.927890
# revt                                               0.659602  0.641823
# txc                                                1.000000  0.949659
# pi                                                 0.949659  1.000000
# txdc                                              -0.371230 -0.200076
# at                                                 0.733850  0.718522
# Total Income Taxes as % of pretax income          -0.000830 -0.000054
# gvkey                                             -0.079902 -0.074629
# Total Income Deferred Taxes as % of pretax income -0.003450 -0.003172
# Total Income Deferred Taxes as % of total assets  -0.024544  0.017409
#
#                                                        txdc        at  \
# tdc1                                              -0.156062  0.427075
# tdc2                                              -0.242926  0.132998
# txt                                               -0.012105  0.703843
# revt                                              -0.139922  0.736987
# txc                                               -0.371230  0.733850
# pi                                                -0.200076  0.718522
# txdc                                               1.000000 -0.209675
# at                                                -0.209675  1.000000
# Total Income Taxes as % of pretax income           0.019111 -0.006533
# gvkey                                              0.000426 -0.120267
# Total Income Deferred Taxes as % of pretax income  0.017728  0.001328
# Total Income Deferred Taxes as % of total assets   0.294072  0.012187
#
#                                                    Total Income Taxes as % of pretax income  \
# tdc1                                                                               0.006133
# tdc2                                                                              -0.018041
# txt                                                                                0.007794
# revt                                                                              -0.000960
# txc                                                                               -0.000830
# pi                                                                                -0.000054
# txdc                                                                               0.019111
# at                                                                                -0.006533
# Total Income Taxes as % of pretax income                                           1.000000
# gvkey                                                                              0.045401
# Total Income Deferred Taxes as % of pretax income                                 -0.607240
# Total Income Deferred Taxes as % of total assets                                   0.036899
#
#                                                       gvkey  \
# tdc1                                              -0.039486
# tdc2                                              -0.013484
# txt                                               -0.085733
# revt                                              -0.093126
# txc                                               -0.079902
# pi                                                -0.074629
# txdc                                               0.000426
# at                                                -0.120267
# Total Income Taxes as % of pretax income           0.045401
# gvkey                                              1.000000
# Total Income Deferred Taxes as % of pretax income -0.039548
# Total Income Deferred Taxes as % of total assets  -0.001208
#
#                                                    Total Income Deferred Taxes as % of pretax income  \
# tdc1                                                                                       -0.017832
# tdc2                                                                                       -0.017925
# txt                                                                                         0.003274
# revt                                                                                       -0.001427
# txc                                                                                        -0.003450
# pi                                                                                         -0.003172
# txdc                                                                                        0.017728
# at                                                                                          0.001328
# Total Income Taxes as % of pretax income                                                   -0.607240
# gvkey                                                                                      -0.039548
# Total Income Deferred Taxes as % of pretax income                                           1.000000
# Total Income Deferred Taxes as % of total assets                                            0.034533
#
#                                                    Total Income Deferred Taxes as % of total assets
# tdc1                                                                                      -0.022141
# tdc2                                                                                      -0.144829
# txt                                                                                        0.092959
# revt                                                                                       0.016442
# txc                                                                                       -0.024544
# pi                                                                                         0.017409
# txdc                                                                                       0.294072
# at                                                                                         0.012187
# Total Income Taxes as % of pretax income                                                   0.036899
# gvkey                                                                                     -0.001208
# Total Income Deferred Taxes as % of pretax income                                          0.034533
# Total Income Deferred Taxes as % of total assets                                           1.000000

# %% [markdown]
# # Combined Key Insights from Summary Statistics and Correlation Matrix:
# ## Total Compensation (tdc1 and tdc2):
#
# *   Both tdc1 and tdc2 show significant variation with large outliers, especially with extremely high compensation values (up to ~$942,779). The presence of zero values in both suggests potential missing compensation for some executives.
# *   Correlation: A moderate positive correlation (0.23) exists between tdc1 and tdc2, indicating that higher total compensation (tdc2) is somewhat associated with higher total compensation (tdc1).
#
# ## Income Taxes as % of Pretax Income:
#
#
#
# *   The average tax burden is 19.4%, but there is substantial variation in this metric, with some companies having negative values (as low as -32.94%), likely due to tax refunds or adjustments.
# *   Correlation: There is no strong correlation with total compensation variables (tdc1 and tdc2), indicating that compensation isn't directly influencing tax rates.
#
# ## Deferred Taxes:
#
# *   Deferred taxes as % of pretax income is generally low (mean: -0.74%), with a high variation (Std: 2.86), showing both liabilities and assets for tax deferrals. Extreme values range from -38.21% to 72.06%. Deferred taxes as % of total assets shows similarly high variability, indicating that some companies have more significant tax deferrals than others (ranging from -39.78% to 26.6%).
# *   Correlation: Both tax deferral variables show weak correlations with total compensation, suggesting that deferred tax strategies don't strongly align with executive pay packages.
#
#
# ## Tax and Compensation Relationships:
#
# *   The weak correlations between total compensation (tdc1, tdc2) and tax-related metrics (Income Taxes as % of pretax income, Deferred Taxes) suggest that executive compensation is not closely linked to tax burden or deferral strategies at a general level. However, outliers (especially in deferred taxes and compensation) may influence this trend.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Scatter plot for tdc1 vs. Total Income Taxes as % of pretax income
plt.figure(figsize=(10, 6))
sns.scatterplot(data=comp_query, x='tdc1', y='Total Income Taxes as % of pretax income')
plt.title('tdc1 vs. Total Income Taxes as % of Pretax Income')
plt.xlabel('Total Compensation (tdc1)')
plt.ylabel('Total Income Taxes as % of Pretax Income')
plt.show()

# %%
# Scatter plot for tdc2 vs. Total Income Taxes as % of pretax income
plt.figure(figsize=(10, 6))
sns.scatterplot(data=comp_query, x='tdc2', y='Total Income Taxes as % of pretax income')
plt.title('tdc2 vs. Total Income Taxes as % of Pretax Income')
plt.xlabel('Total Compensation (tdc2)')
plt.ylabel('Total Income Taxes as % of Pretax Income')
plt.show()

# %%
# Scatter plot for tdc1 vs. Total Income Deferred Taxes as % of pretax income
plt.figure(figsize=(10, 6))
sns.scatterplot(data=comp_query, x='tdc1', y='Total Income Deferred Taxes as % of pretax income')
plt.title('tdc1 vs. Total Income Deferred Taxes as % of Pretax Income')
plt.xlabel('Total Compensation (tdc1)')
plt.ylabel('Total Income Deferred Taxes as % of Pretax Income')
plt.show()

# %%
# Scatter plot for tdc2 vs. Total Income Deferred Taxes as % of pretax income
plt.figure(figsize=(10, 6))
sns.scatterplot(data=comp_query, x='tdc2', y='Total Income Deferred Taxes as % of pretax income')
plt.title('tdc2 vs. Total Income Deferred Taxes as % of Pretax Income')
plt.xlabel('Total Compensation (tdc2)')
plt.ylabel('Total Income Deferred Taxes as % of Pretax Income')
plt.show()

# %%
# Correlation matrix for heatmap
corr_matrix = comp_query[['tdc1', 'tdc2',
                           'Total Income Taxes as % of pretax income',
                           'Total Income Deferred Taxes as % of pretax income',
                           'Total Income Deferred Taxes as % of total assets']].corr()
# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap: Compensation and Tax Metrics')
plt.show()

# %%
# Regression plot for tdc1 vs. Total Income Taxes as % of pretax income
plt.figure(figsize=(10, 6))
sns.regplot(data=comp_query, x='tdc1', y='Total Income Taxes as % of pretax income', scatter_kws={'s':10})
plt.title('Regression Plot: tdc1 vs. Total Income Taxes as % of Pretax Income')
plt.xlabel('Total Compensation (tdc1)')
plt.ylabel('Total Income Taxes as % of Pretax Income')
plt.show()

# %%
# Regression plot for tdc2 vs. Total Income Taxes as % of pretax income
plt.figure(figsize=(10, 6))
sns.regplot(data=comp_query, x='tdc2', y='Total Income Taxes as % of pretax income', scatter_kws={'s':10})
plt.title('Regression Plot: tdc2 vs. Total Income Taxes as % of Pretax Income')
plt.xlabel('Total Compensation (tdc2)')
plt.ylabel('Total Income Taxes as % of Pretax Income')
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select relevant features for clustering
features = comp_query[['tdc1', 'tdc2',
                        'Total Income Taxes as % of pretax income',
                        'Total Income Deferred Taxes as % of pretax income',
                        'Total Income Deferred Taxes as % of total assets']]

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Fit KMeans clustering (choose a number of clusters, e.g., 3)
kmeans = KMeans(n_clusters=5, random_state=42)
comp_query['Cluster'] = kmeans.fit_predict(scaled_features)

# Visualize KMeans clustering with tax and compensation metrics
plt.figure(figsize=(10, 6))
sns.scatterplot(data=comp_query,
                x='Total Income Deferred Taxes as % of total assets',  # X-axis: Tax metric
                y='tdc1',  # Y-axis: Total Compensation (tdc1)
                hue='Cluster', palette='viridis', s=50)
plt.title('KMeans Clustering: Compensation vs.Total Income Deferred Taxes as % of total assets')
plt.xlabel('Total Income Deferred Taxes as % of total assets')
plt.ylabel('Total Compensation (tdc1)')
plt.show()
# Out:
# <ipython-input-29-8244aab16400>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_query['Cluster'] = kmeans.fit_predict(scaled_features)

# %%
# Defining the compensation brackets (for tdc1 and tdc2)
bins_tdc1 = [0, 3394.22, 6192.02, 11068.59, 149429.49]
labels_tdc1 = ['Low', 'Medium-Low', 'Medium-High', 'High']

bins_tdc2 = [0, 3214.20, 6207.09, 11803.38, 942779.92]
labels_tdc2 = ['Low', 'Medium-Low', 'Medium-High', 'High']

# Assign the brackets to the data
comp_query['tdc1_bracket'] = pd.cut(comp_query['tdc1'], bins=bins_tdc1, labels=labels_tdc1, right=False)
comp_query['tdc2_bracket'] = pd.cut(comp_query['tdc2'], bins=bins_tdc2, labels=labels_tdc2, right=False)

# Show the results
comp_query[['tdc1', 'tdc1_bracket', 'tdc2', 'tdc2_bracket']].head()
# Out:
# <ipython-input-30-ddb33c423c2a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_query['tdc1_bracket'] = pd.cut(comp_query['tdc1'], bins=bins_tdc1, labels=labels_tdc1, right=False)
# <ipython-input-30-ddb33c423c2a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_query['tdc2_bracket'] = pd.cut(comp_query['tdc2'], bins=bins_tdc2, labels=labels_tdc2, right=False)
#        tdc1 tdc1_bracket        tdc2 tdc2_bracket
# 0  7865.228  Medium-High   12846.484         High
# 1  3753.703   Medium-Low    3753.703   Medium-Low
# 2  8500.023  Medium-High  123065.368         High
# 3  9994.108  Medium-High    9994.108  Medium-High
# 4  8570.214  Medium-High    8570.214  Medium-High

# %%
#Group by total compensation brackets and calculate mean for tax-related variables
grouped = comp_query.groupby('tdc1_bracket')[['Total Income Taxes as % of pretax income',
                                      'Total Income Deferred Taxes as % of pretax income',
                                      'Total Income Deferred Taxes as % of total assets']].mean()
# Out:
# <ipython-input-31-78c3b24f6818>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = comp_query.groupby('tdc1_bracket')[['Total Income Taxes as % of pretax income',

# %%
# Boxplot for Effective Tax Rate vs Compensation Brackets
plt.figure(figsize=(10,6))
sns.boxplot(x='tdc1_bracket', y='Total Income Taxes as % of pretax income', data=comp_query)
plt.title('Effective Tax Rate vs Total Compensation Bracket')
plt.xlabel('Total Compensation Bracket')
plt.ylabel('Effective Tax Rate')
plt.xticks(rotation=45)
plt.show()

# %%
# Boxplot for Deferred Tax Percentage vs Compensation Brackets
plt.figure(figsize=(10,6))
sns.boxplot(x='tdc1_bracket', y='Total Income Deferred Taxes as % of pretax income', data=comp_query)
plt.title('Deferred Tax Percentage vs Total Compensation Bracket')
plt.xlabel('Total Compensation Bracket')
plt.ylabel('Deferred Tax Percentage')
plt.xticks(rotation=45)
plt.show()

# %%
# Display grouped statistics
print(grouped)
# Out:
#               Total Income Taxes as % of pretax income  \
# tdc1_bracket
# Low                                           0.354857
# Medium-Low                                    0.006776
# Medium-High                                   0.175597
# High                                          0.240214
#
#               Total Income Deferred Taxes as % of pretax income  \
# tdc1_bracket
# Low                                                   -0.129867
# Medium-Low                                             0.326493
# Medium-High                                           -0.055931
# High                                                  -0.170249
#
#               Total Income Deferred Taxes as % of total assets
# tdc1_bracket
# Low                                                  -0.003865
# Medium-Low                                           -0.003473
# Medium-High                                          -0.004325
# High                                                 -0.005723

# %%
# Top 10 companies with the highest total compensation (tdc1 and tdc2)
top_10_tdc1 = comp_query.nlargest(10, 'tdc1')[['gvkey', 'tic', 'tdc1', 'Total Income Taxes as % of pretax income', 'Total Income Deferred Taxes as % of pretax income']]
top_10_tdc2 = comp_query.nlargest(10, 'tdc2')[['gvkey', 'tic', 'tdc2', 'Total Income Taxes as % of pretax income', 'Total Income Deferred Taxes as % of pretax income']]

print("\nTop 10 Companies with Highest tdc1 Total Compensation:")
print(top_10_tdc1)

print("\nTop 10 Companies with Highest tdc2 Total Compensation:")
print(top_10_tdc2)
# Out:
# Top 10 Companies with Highest tdc1 Total Compensation:
#        gvkey   tic        tdc1  Total Income Taxes as % of pretax income  \
# 370    12151  COTY  149429.486                                  0.257662
# 919   126136  CHTR   89077.078                                  0.232419
# 413    14359   PXD   67671.821                                  0.216584
# 406    13824  FICO   66349.962                                  0.224428
# 17      1690  AAPL   63209.845                                  0.147192
# 971   147579  NFLX   49834.936                                  0.128503
# 1027  164296   WBD   49702.546                                  0.202951
# 368    12141  MSFT   48512.537                                  0.189786
# 900   119314  BKNG   46720.734                                  0.217479
# 447    17874  TMUS   37488.850                                  0.243840
#
#       Total Income Deferred Taxes as % of pretax income
# 370                                            0.079881
# 919                                           -0.011672
# 413                                            0.080999
# 406                                           -0.085578
# 17                                             0.000000
# 971                                           -0.074026
# 1027                                           0.606782
# 368                                           -0.067842
# 900                                           -0.087210
# 447                                            0.236385
#
# Top 10 Companies with Highest tdc2 Total Compensation:
#       gvkey   tic        tdc2  Total Income Taxes as % of pretax income  \
# 744   37460  ABNB  942779.918                                 -1.279734
# 954  143912  AXON  323025.293                                 -0.124045
# 706   34410  MRNA  305266.170                                 -0.195840
# 895  117768  NVDA  251495.052                                 -0.044726
# 369   12142  ORCL  242731.808                                  0.067054
# 370   12151  COTY  149429.486                                  0.257662
# 2      1161   AMD  123065.368                                 -0.681102
# 218    7585   MSI  112449.404                                  0.201305
# 432   15414  TECH   79166.650                                  0.157140
# 57     2817   CAT   78459.914                                  0.212080
#
#      Total Income Deferred Taxes as % of pretax income
# 744                                          -1.367745
# 954                                          -0.470981
# 706                                          -0.210046
# 895                                          -0.517580
# 369                                          -0.233236
# 370                                           0.079881
# 2                                            -2.005906
# 218                                          -0.014911
# 432                                          -0.087306
# 57                                           -0.045146

# %%
# Companies with the highest effective tax rates (Top 10 by Total Income Taxes as % of Pretax Income)
top_10_tax_rate = comp_query.nlargest(10, 'Total Income Taxes as % of pretax income')[['gvkey', 'tic', 'Total Income Taxes as % of pretax income', 'tdc1', 'tdc2']]
print("Top 10 Companies with the Highest Effective Tax Rates:")
print(top_10_tax_rate)
# Out:
# Top 10 Companies with the Highest Effective Tax Rates:
#        gvkey   tic  Total Income Taxes as % of pretax income       tdc1  \
# 939   139804  TTMI                                 64.023569   2554.410
# 497    21808   CZR                                 14.800000  18610.359
# 826    63527  SRCL                                  7.454545   7290.832
# 1028  164363  TROX                                  7.408163   5254.719
# 500    22082  JYNT                                  6.949969    434.285
# 887   111534  MSTR                                  4.446063   8028.255
# 781    43026  FTRE                                  4.090909  16320.393
# 538    24216   AES                                  3.625000  12716.194
# 211     7275  MLAB                                  3.390746   5435.566
# 702    33767  SONO                                  3.338188   4728.927
#
#            tdc2
# 939    2554.410
# 497   18610.359
# 826    7290.832
# 1028   5254.719
# 500     434.285
# 887   16926.487
# 781    6320.701
# 538   13753.194
# 211    4674.371
# 702    4728.927

# %%
# Companies with negative or low deferred tax percentages (both in terms of pretax income and total assets)
low_deferred_tax = comp_query[(comp_query['Total Income Deferred Taxes as % of pretax income'] < 0) | (comp_query['Total Income Deferred Taxes as % of total assets'] < 0)]

# Show the companies with negative deferred tax percentages
print("Companies with Negative or Low Deferred Tax Percentages:")
print(low_deferred_tax[['gvkey', 'tic', 'Total Income Deferred Taxes as % of pretax income', 'Total Income Deferred Taxes as % of total assets', 'tdc1', 'tdc2']])
# Out:
# Companies with Negative or Low Deferred Tax Percentages:
#        gvkey   tic  Total Income Deferred Taxes as % of pretax income  \
# 0       1004   AIR                                          -0.018152
# 2       1161   AMD                                          -2.005906
# 3       1209   APD                                          -0.008569
# 7       1327  SWKS                                          -0.140156
# 8       1410   ABM                                          -0.014799
# ...      ...   ...                                                ...
# 1142  192255  ACHC                                           3.705994
# 1144  196268  YELP                                          -0.210788
# 1145  199356  TRIP                                          -0.200000
# 1146  260893  BLKB                                          -1.381093
# 1148  264416  UCTT                                           1.097345
#
#       Total Income Deferred Taxes as % of total assets       tdc1        tdc2
# 0                                            -0.001200   7865.228   12846.484
# 2                                            -0.015011   8500.023  123065.368
# 3                                            -0.000772   9994.108    9994.108
# 7                                            -0.017943   2706.510    3055.487
# 8                                            -0.000993   2503.375    2503.375
# ...                                                ...        ...         ...
# 1142                                         -0.017538   3842.106    3842.106
# 1144                                         -0.021829  11179.479   16558.829
# 1145                                         -0.009854   1942.733    1942.733
# 1146                                         -0.008367   9596.722    9596.722
# 1148                                         -0.006639   5043.765    5043.765
#
# [740 rows x 6 columns]

# %%
# For tdc1
sns.scatterplot(x=top_10_tdc1['tdc1'], y=top_10_tdc1['Total Income Taxes as % of pretax income'])
plt.title('Effective Tax Rate vs Total Compensation (tdc1) for Top 10 Companies')
plt.xlabel('Total Compensation (tdc1)')
plt.ylabel('Effective Tax Rate')
plt.show()

# For tdc2
sns.scatterplot(x=top_10_tdc2['tdc2'], y=top_10_tdc2['Total Income Taxes as % of pretax income'])
plt.title('Effective Tax Rate vs Total Compensation (tdc2) for Top 10 Companies')
plt.xlabel('Total Compensation (tdc2)')
plt.ylabel('Effective Tax Rate')
plt.show()

# %%
# For deferred tax percentage vs tdc1
sns.scatterplot(x=top_10_tdc1['tdc1'], y=top_10_tdc1['Total Income Deferred Taxes as % of pretax income'])
plt.title('Deferred Taxes vs Total Compensation (tdc1) for Top 10 Companies')
plt.xlabel('Total Compensation (tdc1)')
plt.ylabel('Deferred Taxes as % of Pretax Income')
plt.show()

# For deferred tax percentage vs tdc2
sns.scatterplot(x=top_10_tdc2['tdc2'], y=top_10_tdc2['Total Income Deferred Taxes as % of pretax income'])
plt.title('Deferred Taxes vs Total Compensation (tdc2) for Top 10 Companies')
plt.xlabel('Total Compensation (tdc2)')
plt.ylabel('Deferred Taxes as % of Pretax Income')
plt.show()

# %%
sns.boxplot(x=top_10_tax_rate['Total Income Taxes as % of pretax income'], y=top_10_tax_rate['tdc1'])
plt.title('Total Compensation vs Effective Tax Rate (tdc1) for High Tax Companies')
plt.xlabel('Effective Tax Rate')
plt.ylabel('Total Compensation (tdc1)')
plt.show()

sns.boxplot(x=top_10_tax_rate['Total Income Taxes as % of pretax income'], y=top_10_tax_rate['tdc2'])
plt.title('Total Compensation vs Effective Tax Rate (tdc2) for High Tax Companies')
plt.xlabel('Effective Tax Rate')
plt.ylabel('Total Compensation (tdc2)')
plt.show()

# %%
sns.scatterplot(x=low_deferred_tax['tdc1'], y=low_deferred_tax['Total Income Deferred Taxes as % of pretax income'])
plt.title('Deferred Tax Percentage vs Total Compensation for Companies with Low/Negative Deferred Taxes (tdc1)')
plt.xlabel('Total Compensation (tdc1)')
plt.ylabel('Deferred Tax Percentage')
plt.show()

sns.scatterplot(x=low_deferred_tax['tdc2'], y=low_deferred_tax['Total Income Deferred Taxes as % of pretax income'])
plt.title('Deferred Tax Percentage vs Total Compensation for Companies with Low/Negative Deferred Taxes (tdc2)')
plt.xlabel('Total Compensation (tdc2)')
plt.ylabel('Deferred Tax Percentage')
plt.show()

# %%
import statsmodels.api as sm

# Define the variables
X_raw = comp_query['tdc1']
y_raw = comp_query['Total Income Taxes as % of pretax income']

# Combine into a DataFrame to compute IQR
df = pd.DataFrame({'tdc1': X_raw, 'tax_rate': y_raw})

# Remove rows with NaN values (important before outlier filtering)
df = df.dropna()

# IQR method to remove outliers
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# Filter out outliers
filtered_df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# Prepare data for regression
X = sm.add_constant(filtered_df['tdc1'])
y = filtered_df['tax_rate']

# Fit model
model = sm.OLS(y, X).fit()

# Summary of results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               tax_rate   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     6.518
# Date:                Mon, 14 Apr 2025   Prob (F-statistic):             0.0108
# Time:                        01:00:05   Log-Likelihood:                 814.22
# No. Observations:                 932   AIC:                            -1624.
# Df Residuals:                     930   BIC:                            -1615.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1729      0.006     29.727      0.000       0.161       0.184
# tdc1        1.685e-06    6.6e-07      2.553      0.011     3.9e-07    2.98e-06
# ==============================================================================
# Omnibus:                       59.754   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.818
# Skew:                          -0.662   Prob(JB):                     6.91e-16
# Kurtosis:                       3.216   Cond. No.                     1.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Fit the model
model = sm.OLS(y, X).fit()

# Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=comp_query['tdc1'], y=y, label="Data", color="blue")

# Regression line
x_range = np.linspace(comp_query['tdc1'].min(), comp_query['tdc1'].max(), 100)
X_pred = sm.add_constant(x_range)  # Add constant for intercept
y_pred = model.predict(X_pred)

plt.plot(x_range, y_pred, color='red', label="Regression Line")

# Labels and title
plt.xlabel("Total Compensation (tdc1)")
plt.ylabel("Total Income Taxes as % of Pretax Income")
plt.title("Regression: Compensation vs Effective Tax Rate")
plt.legend()
plt.show()
